# %% [markdown]
# <a href="https://colab.research.google.com/github/praveenbunker098-lgtm/45-days-of-python/blob/main/DAY4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # *Function*

# %% [markdown]
# *   function declare by 'def'- keyword
# *   parameter- Function banate time variable
# *   argument - Function call karte time di hui value

# %%
# #function

# def hello():
#   print("hello fnction is working")

# hello()

# # example2
# def hello1(a): # a as paramenter
#   print(a)
# hello1(100) # 100 is parameter

# # example3
# def add(a=5,b=5):
#   print(a+b)
# add(5,6)

# # example4

# def power(a,b):
#   print(a**b)

# power(5,3)
# power(2,4)
# power(b = 6,a=7)

# # Example5

# def student(*a):
#   print(a)
#   print(type(a))
#   print(a[0])
# student(1,2,3,4,5,6,7)

#question

def marks(a):
    for i in a:
        print(i)

marks([10,20,30,40,50])

#question2

# def address(a):
#   for i in a[0],b[1]:
#     print(i)


# address(["hello", "praveen"])



#example

def sum(a,b):
  return a + b

sum(10,20)
# Out:
# 10
# 20
# 30
# 40
# 50
# 30

# %% [markdown]
# Lambda function(lambda argument : expression)

# %%
# add = lambda x : x
# print(add(100))


# sum = lambda x, y :x+y
# print(sum(40,50))


#question
a = lambda *x: [i for i in x]
print (a(10,20,30))
# Out:
# [10, 20, 30]

# %% [markdown]
# ### **List comprehensions [ expression for item in iterable]**

# %%
l = [10,20,30,40,50,60]

print([l[i] for i in range(2, len(l))])
# Out:
# [30, 40, 50, 60]

# %% [markdown]
# # *LIST*

# %%
# L = [10,20,30]
# len(L)
# print(L[0])
# print(L[1])
# print(L[2])
# print(L[-1])
# print(L[-2])
# print(L[-3])
# L.append(40)
# L.insert(1,100)
# print(L)


# #question
# L = [10,20,30,40,"hello", True]
# print(L)
# print(L[0])
# print(L[1])
# print(L[2])
# print(L[3])
# print(L[4])
# print(L[5])
# L.append("praveen")
# print(L)
# L.insert(1,"praveennnnnnn")
# print(L)
# L.remove("praveennnnnnn")
# print(L)

#queston2

# L = [10,20,30,{"name":"praveennn","address":["jaipur","kukas","achrol","friend house"]}]
# print(L)
# print(L[3])
# print(L[-1]['address'])
# for i in L[3]['address']:
#   print(i)


#question

l = [10,20,30,[40,50,[60, 70, 80]]]
for i in range(len(l[3]) -1):
  print(l[3][i])
# Out:
# 40
# 50

# %% [markdown]
# ## ***DICTIONARY***

# %%
data = {
  "Message": "Number of Post office(s) found: 6",
  "Status": "Success",
  "PostOffice": [
    {
      "Name": "Achrol",
      "Description": "",
      "BranchType": "Sub Post Office",
      "DeliveryStatus": "Delivery",
      "Taluk": "Jaipur",
      "Circle": "Jaipur",
      "District": "Jaipur",
      "Division": "Jaipur Moffusil",
      "Region": "Jaipur HQ",
      "State": "Rajasthan",
      "Country": "India"
    },
    {
      "Name": "Jaitpura Khinchi",
      "Description": "",
      "BranchType": "Branch Post Office",
      "DeliveryStatus": "Delivery",
      "Taluk": "Jaipur",
      "Circle": "Jaipur",
      "District": "Jaipur",
      "Division": "Jaipur Moffusil",
      "Region": "Jaipur HQ",
      "State": "Rajasthan",
      "Country": "India"
    },
    {
      "Name": "Kali Pahadi",
      "Description": "",
      "BranchType": "Branch Post Office",
      "DeliveryStatus": "Delivery",
      "Taluk": "Jaipur",
      "Circle": "Jaipur",
      "District": "Jaipur",
      "Division": "Jaipur Moffusil",
      "Region": "Jaipur HQ",
      "State": "Rajasthan",
      "Country": "India"
    },
    {
      "Name": "Kant",
      "Description": "",
      "BranchType": "Branch Post Office",
      "DeliveryStatus": "Delivery",
      "Taluk": "Jaipur",
      "Circle": "Jaipur",
      "District": "Jaipur",
      "Division": "Jaipur Moffusil",
      "Region": "Jaipur HQ",
      "State": "Rajasthan",
      "Country": "India"
    },
    {
      "Name": "Labana",
      "Description": "",
      "BranchType": "Branch Post Office",
      "DeliveryStatus": "Delivery",
      "Taluk": "Jaipur",
      "Circle": "Jaipur",
      "District": "Jaipur",
      "Division": "Jaipur Moffusil",
      "Region": "Jaipur HQ",
      "State": "Rajasthan",
      "Country": "India"
    },
    {
      "Name": "Rajpurawas Tala",
      "Description": "",
      "BranchType": "Branch Post Office",
      "DeliveryStatus": "Delivery",
      "Taluk": "Jaipur",
      "Circle": "Jaipur",
      "District": "Jaipur",
      "Division": "Jaipur Moffusil",
      "Region": "Jaipur HQ",
      "State": "Rajasthan",
      "Country": "India"
    }
  ]
}

for i in data["PostOffice"]:
    for j in i:
        print(i[j])

    print("------------")

# for i in data["PostOffice"] ek ek karke har post office ko uthata hai.
# Pehli baar i me "Achrol" wala data aayega.
# Dusri baar i me "Jaitpura Khinchi" wala data aayega.

# i ek dictionary hai.
# Jab dictionary par loop chalate ho to keys milti hain.
# Yaha j me keys aayengi:
# Out:
# Achrol
#
# Sub Post Office
# Delivery
# Jaipur
# Jaipur
# Jaipur
# Jaipur Moffusil
# Jaipur HQ
# Rajasthan
# India
# ------------
# Jaitpura Khinchi
#
# Branch Post Office
# Delivery
# Jaipur
# Jaipur
# Jaipur
# Jaipur Moffusil
# Jaipur HQ
# Rajasthan
# India
# ------------
# Kali Pahadi
#
# Branch Post Office
# Delivery
# Jaipur
# Jaipur
# Jaipur
# Jaipur Moffusil
# Jaipur HQ
# Rajasthan
# India
# ------------
# Kant
#
# Branch Post Office
# Delivery
# Jaipur
# Jaipur
# Jaipur
# Jaipur Moffusil
# Jaipur HQ
# Rajasthan
# India
# ------------
# Labana
#
# Branch Post Office
# Delivery
# Jaipur
# Jaipur
# Jaipur
# Jaipur Moffusil
# Jaipur HQ
# Rajasthan
# India
# ------------
# Rajpurawas Tala
#
# Branch Post Office
# Delivery
# Jaipur
# Jaipur
# Jaipur
# Jaipur Moffusil
# Jaipur HQ
# Rajasthan
# India
# ------------
