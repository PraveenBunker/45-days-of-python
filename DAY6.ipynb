# %% [markdown]
# <a href="https://colab.research.google.com/github/praveenbunker098-lgtm/45-days-of-python/blob/main/DAY6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## ***Importing & Using Modules***

# %%
# import math


# print(math.factorial(4))
# print(math.sqrt(5))
# print(math.pow(6,3))
# print(math.pi)
# print(math.floor)


# # import math as praveen

# import math as praveen


# print(praveen.factorial(4))
# print(praveen.sqrt(5))
# print(praveen.pow(6,3))
# print(praveen.pi)
# print(praveen.floor)


# example 2

from math import factorial,pi

print(factorial(4))
print(pi)


#example3

from math import *

print(factorial(4))
print(pi)
print(sqrt(5))
print(pow(6,3))
# Out:
# 24
# 3.141592653589793
# 24
# 3.141592653589793
# 2.23606797749979
# 216.0
