# %% [markdown]
# <a href="https://colab.research.google.com/github/PraveenBunker/45-days-of-python/blob/main/DAY11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PANDAS**

# %% [markdown]
#  *  It is a package useful for data analysis and manipulation.
#
#    •    Pandas provide an easy way to create, manipulate and wrangle the
# data.
#
# • Pandas provide powerful and easy-to-use data structures, as well
# as the means to quickly perform operations on these structures.

# %%
import pandas as pd
import numpy as np

arr=np.array([10,20,30,40,50])
s = pd.Series(arr)
print(s)
print(s.head(3))
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
import pandas as pd
df = pd.Series([10,20,30,40,50])
print(df)
# Out:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64

# %%
# dict

dict = {"name":["praveen","abhishek","kunal","dheeraj"],
        "age":[20,21,23,21],
        "salary":[{"In-hand":"15000","ctc":"1.2lpa"},
                  {"In-hand":"25000","ctc":"3.3lpa"},
                  {"In-hand":"15000","ctc":"4.3lpa"},
                  {"In-hand":"34000","ctc":"3.3lpa"}
                  ]
        }
df = pd.DataFrame(dict)
print(df)
# Out:
#        name  age                                 salary
# 0   praveen   20  {'In-hand': '15000', 'ctc': '1.2lpa'}
# 1  abhishek   21  {'In-hand': '25000', 'ctc': '3.3lpa'}
# 2     kunal   23  {'In-hand': '15000', 'ctc': '4.3lpa'}
# 3   dheeraj   21  {'In-hand': '34000', 'ctc': '3.3lpa'}

# %%
dict = {"name":["praveen","abhishek","kunal","dheeraj"],
        "age":[20,21,23,21],
        "salary":[50000,60000,70000,80000]

        }
df = pd.DataFrame(dict)
print(df)
# Out:
#        name  age  salary
# 0   praveen   20   50000
# 1  abhishek   21   60000
# 2     kunal   23   70000
# 3   dheeraj   21   80000

# %% [markdown]
# csv

# %%
# csv
import pandas as pd
url = "https://raw.githubusercontent.com/praveenbunker098-lgtm/45-days-of-python/main/file2%20-%20Sheet1.csv"
df  = pd.read_csv(url)
print(df)
# Out:
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50

# %%
# JSON
import pandas as pd
url = "https://raw.githubusercontent.com/praveenbunker098-lgtm/45-days-of-python/main/file2.json"
df  = pd.read_json(url)
print(df)
# Out:
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50

# %%
#Excel
import pandas as pd
url = "https://raw.githubusercontent.com/praveenbunker098-lgtm/45-days-of-python/main/file2.xlsx"
df  = pd.read_excel(url)
print(df)
# Out:
#        name  roll no  marks
# 0   dheeraj      123     10
# 1     kunal     1234     20
# 2  abhishek    12345     30
# 3   praveen    12356     40
# 4    anjali  1234567     50
